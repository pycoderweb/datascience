# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/automobile_data_nan.csv")
df.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible         NaN   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         NaN             21.0  13495.0
# 1             four       111.0             21.0  16500.0
# 2              six       154.0              NaN  16500.0
# 3             four       102.0             24.0  13950.0
# 4             five         NaN              NaN  17450.0

# %%
df.isnull().sum()/len(df)*100
# Out:
# index                0.000000
# company              0.000000
# body-style           0.000000
# wheel-base          24.590164
# length              21.311475
# engine-type         19.672131
# num-of-cylinders     0.000000
# horsepower          26.229508
# average-mileage     24.590164
# price                4.918033
# dtype: float64

# %%
df.dropna(thresh=8)
# Out:
# 56

# %%
df.dropna(subset=['price'])
# Out:
# (58, 10)

# %%
df.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible         NaN   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         NaN             21.0  13495.0
# 1             four       111.0             21.0  16500.0
# 2              six       154.0              NaN  16500.0
# 3             four       102.0             24.0  13950.0
# 4             five         NaN              NaN  17450.0

# %%
df.fillna({'wheel-base':np.mean(df['wheel-base'])})
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible   88.600000   168.8        dohc
# 1       1  alfa-romero  convertible   99.219565   168.8        dohc
# 2       2  alfa-romero    hatchback   94.500000   171.2        ohcv
# 3       3         audi        sedan   99.800000   176.6         ohc
# 4       4         audi        sedan   99.400000   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan   97.300000   171.7         ohc
# 57     82   volkswagen        sedan   99.219565   171.7         NaN
# 58     86   volkswagen        sedan   97.300000     NaN         ohc
# 59     87        volvo        sedan  104.300000   188.8         NaN
# 60     88        volvo        wagon  104.300000   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         NaN             21.0  13495.0
# ...

# %%
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible         NaN   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan         NaN   171.7         NaN
# 58     86   volkswagen        sedan        97.3     NaN         ohc
# 59     87        volvo        sedan       104.3   188.8         NaN
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         NaN             21.0  13495.0
# ...

# %%
np.mean(df['wheel-base'])
# Out:
# 99.2195652173913

# %%
df[df.company=='audi'].fillna(method='ffill')
# Out:
#    index company body-style  wheel-base  length engine-type num-of-cylinders  \
# 3      3    audi      sedan        99.8   176.6         ohc             four
# 4      4    audi      sedan        99.4   176.6         ohc             five
# 5      5    audi      sedan        99.8   177.3         ohc             five
# 6      6    audi      wagon       105.8   192.7         ohc             five
#
#    horsepower  average-mileage    price
# 3       102.0             24.0  13950.0
# 4       102.0             24.0  17450.0
# 5       110.0             19.0  15250.0
# 6       110.0             19.0  18920.0

# %%
df1 = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/world_population_duplicates.csv")
df1.head()
# Out:
#    rank  country     density   densityMi    pop2021   area
# 0     1    Macau  21946.4667  56841.3487    658.394     30
# 1     2   Monaco  19755.5000  51166.7450     39.511      2
# 2    28  Burundi    440.3044   1140.3884  12255.433  27834
# 3     1    Macau  21946.4667  56841.3487    658.394     30
# 4     2   Monaco  19755.5000  51166.7450     39.511      2

# %%
df1.drop_duplicates(['country','rank'])
# Out:
#      rank           country     density   densityMi    pop2021     area
# 0       1             Macau  21946.4667  56841.3487    658.394       30
# 1       2            Monaco  19755.5000  51166.7450     39.511        2
# 2      28           Burundi    440.3044   1140.3884  12255.433    27834
# 5       3         Singapore   8305.1915  21510.4461   5896.686      710
# 6       4         Hong Kong   6841.3134  17719.0017   7552.810     1104
# ..    ...               ...         ...         ...        ...      ...
# 242   228           Namibia      3.1338      8.1166   2587.344   825615
# 243   229    Western Sahara      2.3003      5.9577    611.875   266000
# 244   230          Mongolia      2.1286      5.5129   3329.289  1564110
# 245   231  Falkland Islands      0.2902      0.7517      3.533    12173
# 246   232         Greenland      0.0263      0.0680     56.877  2166086
#
# [232 rows x 6 columns]

# %%
len(df1)-len(df1.drop_duplicates())==df1.duplicated().sum()
# Out:
# True

# %%
df1.head()
# Out:
#    rank  country     density   densityMi    pop2021   area
# 0     1    Macau  21946.4667  56841.3487    658.394     30
# 1     2   Monaco  19755.5000  51166.7450     39.511      2
# 2    28  Burundi    440.3044   1140.3884  12255.433  27834
# 3     1    Macau  21946.4667  56841.3487    658.394     30
# 4     2   Monaco  19755.5000  51166.7450     39.511      2

# %%
df.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible         NaN   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         NaN             21.0  13495.0
# 1             four       111.0             21.0  16500.0
# 2              six       154.0              NaN  16500.0
# 3             four       102.0             24.0  13950.0
# 4             five         NaN              NaN  17450.0

# %%
df['num-of-cylinders'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
data = {'four':4, 'six':6, 'five':5, 'three':3, 'twelve':11, 'two':2, 'eight':8}
df['cylinders'] = df['num-of-cylinders'].map(data)
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible         NaN   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan         NaN   171.7         NaN
# 58     86   volkswagen        sedan        97.3     NaN         ohc
# 59     87        volvo        sedan       104.3   188.8         NaN
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price  cylinders
# 0              four         NaN             21.0  13495.0          4
# ...

# %%
df['price_uz'] = df['price'].map(lambda x:x*11440)
df.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible         NaN   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price     price_uz
# 0             four         NaN             21.0  13495.0  154382800.0
# 1             four       111.0             21.0  16500.0  188760000.0
# 2              six       154.0              NaN  16500.0  188760000.0
# 3             four       102.0             24.0  13950.0  159588000.0
# 4             five         NaN              NaN  17450.0  199628000.0

# %%
df.replace({'four':4})
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible         NaN   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan         NaN   171.7         NaN
# 58     86   volkswagen        sedan        97.3     NaN         ohc
# 59     87        volvo        sedan       104.3   188.8         NaN
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price     price_uz
# 0                 4         NaN             21.0  13495.0  154382800.0
# ...

# %%
df.horsepower.replace(np.nan, 'yuq',inplace=True)
df.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible         NaN   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders horsepower  average-mileage    price     price_uz
# 0             four        yuq             21.0  13495.0  154382800.0
# 1             four      111.0             21.0  16500.0  188760000.0
# 2              six      154.0              NaN  16500.0  188760000.0
# 3             four      102.0             24.0  13950.0  159588000.0
# 4             five        yuq              NaN  17450.0  199628000.0

# %%
df.rename(index=str.upper, columns=str.upper)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-b79effacb3e3> in <cell line: 1>()
# ----> 1 df.rename(index=str.upper, columns=str.upper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    5571         4  3  6
#    5572         """
# -> 5573         return super()._rename(
#    5574             mapper=mapper,
#    5575             index=index,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    1102                     raise KeyError(f"{missing_labels} not found in axis")
#    1103
# -> 1104             new_index = ax._transform_index(f, level=level)
#    1105             result._set_axis_nocheck(new_index, axis=axis_no, inplace=True, copy=False)
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/world_population_duplicates.csv', usecols=['country','pop2021','area'], index_col='country')
df.head()
# Out:
#            pop2021   area
# country
# Macau      658.394     30
# Monaco      39.511      2
# Burundi  12255.433  27834
# Macau      658.394     30
# Monaco      39.511      2

# %%
population = df.pop2021
population
# Out:
# country
# Macau                 658.394
# Monaco                 39.511
# Burundi             12255.433
# Macau                 658.394
# Monaco                 39.511
#                       ...
# Namibia              2587.344
# Western Sahara        611.875
# Mongolia             3329.289
# Falkland Islands        3.533
# Greenland              56.877
# Name: pop2021, Length: 247, dtype: float64

# %%
population.value_counts()
# Out:
# 1273.433     3
# 6769.146     3
# 658.394      2
# 39.234       2
# 6518.499     2
#             ..
# 5813.298     1
# 31732.129    1
# 1215.584     1
# 57.917       1
# 56.877       1
# Name: pop2021, Length: 232, dtype: int64

# %%
population.sort_values()
# Out:
# country
# Vatican City              0.800
# Tokelau                   1.373
# Niue                      1.619
# Falkland Islands          3.533
# Montserrat                4.977
#                        ...
# Pakistan             225199.937
# Indonesia            276361.783
# United States        332915.073
# India               1393409.038
# China               1444216.107
# Name: pop2021, Length: 247, dtype: float64

# %%
guruh = [0,100,1000,100000,10000000]
pd.cut(population,guruh).value_counts()
# Out:
# (1000, 100000]        153
# (100, 1000]            44
# (0, 100]               36
# (100000, 10000000]     14
# Name: pop2021, dtype: int64

# %%
guruh_nomlar = ['juda kam','kam','orta','kop']
pd.cut(population,guruh,labels=guruh_nomlar).value_counts()
# Out:
# orta        153
# kam          44
# juda kam     36
# kop          14
# Name: pop2021, dtype: int64

# %%
pd.qcut(population,4).value_counts()
# Out:
# (0.799, 423.223]            62
# (423.223, 5460.721]         62
# (19430.022, 1444216.107]    62
# (5460.721, 19430.022]       61
# Name: pop2021, dtype: int64

# %%
import numpy as np

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/automobile_data.csv", index_col=0)
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# 3                 four         102               24  13950.0
# 4                 five         115               18  17450.0

# %%
df.company.value_counts()
# Out:
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# audi             4
# mercedes-benz    4
# mitsubishi       4
# volkswagen       4
# alfa-romero      3
# chevrolet        3
# honda            3
# isuzu            3
# jaguar           3
# porsche          3
# dodge            2
# volvo            2
# Name: company, dtype: int64

# %%
df.groupby('company').price.mean()
# Out:
# company
# alfa-romero      15498.333333
# audi             16392.500000
# bmw              27213.333333
# chevrolet         6007.000000
# dodge             6303.000000
# honda            10195.000000
# isuzu             6785.000000
# jaguar           34600.000000
# mazda             9654.800000
# mercedes-benz    35040.000000
# mitsubishi        6689.000000
# nissan            8289.000000
# porsche          35528.000000
# toyota            8216.857143
# volkswagen        8435.000000
# volvo            13177.500000
# Name: price, dtype: float64

# %%
df.groupby(['company','body-style']).price.max()
# Out:
# company        body-style
# alfa-romero    convertible    16500.0
#                hatchback      16500.0
# audi           sedan          17450.0
#                wagon          18920.0
# bmw            sedan          41315.0
# chevrolet      hatchback       6295.0
#                sedan           6575.0
# dodge          hatchback       6377.0
# honda          sedan          12945.0
#                wagon           7295.0
# isuzu          sedan           6785.0
# jaguar         sedan          36000.0
# mazda          hatchback      11845.0
#                sedan          18344.0
# mercedes-benz  hardtop        45400.0
#                sedan          40960.0
#                wagon          28248.0
# mitsubishi     hatchback       6189.0
#                sedan           8189.0
# nissan         sedan          13499.0
#                wagon           7349.0
# porsche        convertible    37028.0
#                hardtop        34028.0
#                hatchback          NaN
# ...

# %%
df.groupby(['company','body-style']).agg([max,min,np.mean])
# Out:
# <ipython-input-48-e8d6d9ce3653>:1: FutureWarning: ['engine-type', 'num-of-cylinders'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby(['company','body-style']).agg([max,min,np.mean])
#                           wheel-base                    length         \
#                                  max    min        mean    max    min
# company       body-style
# alfa-romero   convertible       88.6   88.6   88.600000  168.8  168.8
#               hatchback         94.5   94.5   94.500000  171.2  171.2
# audi          sedan             99.8   99.4   99.666667  177.3  176.6
#               wagon            105.8  105.8  105.800000  192.7  192.7
# bmw           sedan            110.0  101.2  103.433333  197.0  176.8
# chevrolet     hatchback         94.5   88.4   91.450000  155.9  141.1
#               sedan             94.5   94.5   94.500000  158.8  158.8
# ...

# %%
df.describe()
# Out:
#        wheel-base      length  horsepower  average-mileage         price
# count   61.000000   61.000000   61.000000        61.000000     58.000000
# mean    98.481967  173.098361  107.852459        25.803279  15387.000000
# std      6.679234   14.021846   53.524398         8.129821  11320.259841
# min     88.400000  141.100000   48.000000        13.000000   5151.000000
# 25%     94.500000  159.100000   68.000000        19.000000   6808.500000
# 50%     96.300000  171.200000  100.000000        25.000000  11095.000000
# 75%    101.200000  177.300000  123.000000        31.000000  18120.500000
# max    120.900000  208.100000  288.000000        47.000000  45400.000000

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/MOCK_USER_DATA.csv", index_col=0)
df.head()
# Out:
#    first_name   last_name                           email       gender   age
# id
# 1     Dorothy     Verryan               dverryan0@who.int   Non-binary     1
# 2     Pietrek     Scanlin          pscanlin1@yolasite.com         Male    91
# 3      Lilith    Sarjeant  lsarjeant2@creativecommons.org  Genderfluid  1233
# 4        Knox  Cunningham    kcunningham3@yellowpages.com  Genderfluid     6
# 5    Mohammed  Habbershon    mhabbershon4@sourceforge.net       Female    48

# %%
df['age'] = df['age'].apply(np.abs)
df.drop(index=df[df.age>123].index,inplace=True)
df.describe()
# Out:
#               age
# count   93.000000
# mean    52.612903
# std     29.978265
# min      1.000000
# 25%     29.000000
# 50%     52.000000
# 75%     77.000000
# max    100.000000

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/blob/main/melb_data.csv?raw=true")
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
df.isna().sum().value_counts()
# Out:
# 0       18
# 6417     1
# 5344     1
# 1307     1
# dtype: int64

# %%
df[['BuildingArea','YearBuilt']].apply(np.mean)
# Out:
# BuildingArea     152.128903
# YearBuilt       1964.896501
# dtype: float64

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df.fillna({'BuildingArea':df['BuildingArea'].mean(),'YearBuilt':int(df['YearBuilt'].mean())})
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13513  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13514   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13515   Williamstown       83 Power St      3    h  1170000.0      S
# 13516   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13517     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
df.groupby(df['Regionname']).YearBuilt.mean().astype(int)
# Out:
# Regionname
# Eastern Metropolitan          1971
# Eastern Victoria              1984
# Northern Metropolitan         1962
# Northern Victoria             1986
# South-Eastern Metropolitan    1976
# Southern Metropolitan         1960
# Western Metropolitan          1968
# Western Victoria              1982
# Name: YearBuilt, dtype: int64

# %%
df['Regionname']
# Out:
# 0             Northern Metropolitan
# 1             Northern Metropolitan
# 2             Northern Metropolitan
# 3             Northern Metropolitan
# 4             Northern Metropolitan
#                     ...
# 13513    South-Eastern Metropolitan
# 13514          Western Metropolitan
# 13515          Western Metropolitan
# 13516          Western Metropolitan
# 13517          Western Metropolitan
# Name: Regionname, Length: 13518, dtype: object

# %%
df['YearBuilt']
# Out:
# 0           NaN
# 1        1900.0
# 2        1900.0
# 3           NaN
# 4        2014.0
#           ...
# 13513    1981.0
# 13514    1995.0
# 13515    1997.0
# 13516    1920.0
# 13517    1920.0
# Name: YearBuilt, Length: 13518, dtype: float64

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
groups = df.groupby(['Regionname']).YearBuilt.mean() # Bu Series obyekti
for idx in groups.index:
   df[df.Regionname==idx] = df[df.Regionname==idx].fillna({'YearBuilt':groups[idx]})
groups
# Out:
# Regionname
# Eastern Metropolitan          1971.856106
# Eastern Victoria              1984.032258
# Northern Metropolitan         1962.965386
# Northern Victoria             1986.666667
# South-Eastern Metropolitan    1976.859504
# Southern Metropolitan         1960.887041
# Western Metropolitan          1968.236292
# Western Victoria              1982.565217
# Name: YearBuilt, dtype: float64
